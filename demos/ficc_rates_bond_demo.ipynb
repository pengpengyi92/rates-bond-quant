# %% [markdown]
# # FICC Rates Bond Quant
#
# This notebook demonstrates bond pricing, modified duration, convexity, and rate-shock PnL using public-safe synthetic assumptions.

# %%
from ficc_rates_bond_quant import compare_maturities, rate_cut

rows = compare_maturities(scenario=rate_cut(10))
rows[:2]

# %% [markdown]
# A rate cut increases bond prices in this simplified setup. Longer maturity bonds usually show higher duration and larger PnL sensitivity.
